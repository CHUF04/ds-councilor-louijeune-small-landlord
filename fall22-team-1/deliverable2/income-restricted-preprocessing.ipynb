# %%
import pandas as pd

df = pd.read_csv('../data/income-restricted-inventory-2021.csv', dtype={'Zip Code':str})
df
# Out:
#                    Project Name Neighborhood Zip Code  TtlProjUnits  \
# 0     Abbot Street/ Shawmut Ave      Roxbury     2119            16
# 1               Academy Homes I      Roxbury     2119           202
# 2              Academy Homes II      Roxbury     2119           236
# 3           Adams Court Phase A     Mattapan     2126            50
# 4           Adams Court Phase B     Mattapan     2126            45
# ...                         ...          ...      ...           ...
# 1440     xxxxxxxx Blue Hill Ave      Roxbury     2119             4
# 1441   YouthBuild Ruskindale Rd    Hyde Park     2136             1
# 1442              YWCA Berkeley    South End     2116           208
# 1443          YWCA Boston Units     Back Bay     2116           115
# 1444          Zebra Condominium    South End     2118            10
#
#       RentUnits  OwnUnits  TtlMarket  MarketRent  MarketOwn  \
# 0            16         0        0.0         0.0        0.0
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

rental_units = np.array(sorted(df['RentUnits'], reverse=True))
plt.title('Numbers of rental units')
plt.plot(rental_units)

# %%
plt.title('Numbers of rental units no more than 16')
plt.plot(rental_units[rental_units<=16])
k=10
plt.axhline(k, color='r')

# %%
df_non_comm = df[df['RentUnits']<=k]
df_non_comm = df_non_comm[df_non_comm['RentUnits'] > 0]
df_non_comm
# Out:
#                  Project Name  Neighborhood Zip Code  TtlProjUnits  RentUnits  \
# 10         Alleyne (VUP) CDFI       Roxbury    02121             3          2
# 18              Andrade (VUP)    Dorchester    02122             3          2
# 19         Andrew Square Apts  South Boston    02127             9          9
# 41               Bailey (VUP)       Roxbury    02121             1          1
# 45             Baptista (VUP)    Dorchester    02125             1          1
# ...                       ...           ...      ...           ...        ...
# 1434  xxxxx Clarkson St (REO)    Dorchester    02125             3          2
# 1437     xxxxxx Washington St    Dorchester    02124             2          2
# 1439    xxxxxxx Blue Hill Ave       Roxbury    02119            10         10
# 1440   xxxxxxxx Blue Hill Ave       Roxbury    02119             4          4
# 1444        Zebra Condominium     South End    02118            10          7
#
# ...

# %%
# df_non_comm.to_csv('../data/income-restricted-non-commercial.csv')

# %%
from matplotlib.pyplot import figure

figure(figsize=(12, 8))
plt.title('Income-restricted Housing by Neighborhood')
plt.xticks(rotation=90)
plt.hist(df_non_comm['Neighborhood'])
# Out:
# (array([267.,   6.,  28.,  20.,  45.,  16.,   3.,  13.,   1.,   4.]),
#  array([ 0. ,  1.4,  2.8,  4.2,  5.6,  7. ,  8.4,  9.8, 11.2, 12.6, 14. ]),
#  <BarContainer object of 10 artists>)
