# %%
import pandas as pd

main_df = pd.read_csv('../data/main_dataset.csv')
affordable_df = pd.read_csv('../data/affordable_units.csv')
# main_df
print(affordable_df)
affordable_df.head()
# Out:
#      Neighborhood                              Building Address  \
# 0         Allston                               8 Griggs Street
# 1         Allston                        31 North Beacon Street
# 2         Allston                             40 Malvern Street
# 3         Allston                          450 Cambridge Street
# 4         Allston                      1505 Commonwealth Avenue
# ..            ...                                           ...
# 112      West End                          Avalon North Station
# 113      West End           Emerson Place\n1 & 10 Emerson Place
# 114  West Roxbury           Belgrade Place\n446 Belgrade Avenue
# 115  West Roxbury  Residences at Snow Place\n1215 Centre Street
# 116  West Roxbury                     Oak Row\n1235 VFW Parkway
#
#             For Current Vacancies and More Information  \
# 0               The Mount Vernon Company: 617.267.0006
# 1                      Carol Fiore: cfiore@78clean.com
# ...
