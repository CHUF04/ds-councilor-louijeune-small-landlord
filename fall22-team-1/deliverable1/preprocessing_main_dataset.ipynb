# %%
# !pip install geopy

# %%
import pandas as pd
import time
from geopy.geocoders import Nominatim

# %%
# setup geopy
geolocator = Nominatim(user_agent="preprocessing_main_dataset")

# %%
def find_coordinates(df_row):
    addr = df_row['ST_NUM']+df_row['ST_NAME']+' '+df_row['CITY']+' '+df_row['ZIPCODE']
    # prevent too many requests from being sent in one short time interval
    time.sleep(0.1)
    try:
        location = geolocator.geocode(addr)
    except Exception as e:
        print("Error", e, "while getting", addr)
        return (pd.NA, pd.NA)
    
    if location == None:
        print("No location for", addr)
        return (pd.NA, pd.NA)
    else:
        print("Found location for", addr)
        return (location.latitude, location.longitude)

def fix_zip(zip):
    if len(zip) == 4:
        return '0' + zip
    else:
        return zip

# %%
# add coordinates to main dataset using geopy
df = pd.read_csv('../data/main_dataset.csv')
# fix the zipcode column
df['ZIPCODE'] = df['ZIPCODE'].astype(str).apply(fix_zip)
# take a sample
df_sample = df.sample(n=500, random_state=20, axis=0)
df_sample['coordinates'] = df_sample.apply(find_coordinates, axis=1)
df_sample.to_csv('../data/preprocessed_main_dataset_rsample.csv')
# Out:
# Found location for 9  STEARNS RD
# No location for 102  108ELM HILL AV
# Found location for 133  SEAPORT BLVD
# Found location for 1  HADLEY ST
# Found location for   OAKLAND ST
# Found location for 257  SAVIN HILL AV
# No location for 5  7WOODFIELD ST
# Found location for 39  FREELAND ST
# Found location for 1945  COMMONWEALTH AV
# No location for 38  40ST BOTOLPH ST
# Found location for 15  MONUMENT SQ
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/yg/zpnh1p_d4qvg_bz_487cbyp00000gn/T/ipykernel_43418/1474130392.py in <module>
#       5 # take a sample
#       6 df_sample = df.sample(n=500, random_state=20, axis=0)
# ----> 7 df_sample['coordinates'] = df_sample.apply(find_coordinates, axis=1)
#       8 df_sample.to_csv('../data/preprocessed_main_dataset_rsample.csv')
#
# ...
